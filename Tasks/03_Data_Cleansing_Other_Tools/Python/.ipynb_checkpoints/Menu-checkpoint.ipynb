# %%
import pandas as pd

# %% [markdown]
# # MENU

# %%
with open('..\Data\Menu.csv','r',encoding='utf-8') as f:
    menu_df = pd.read_csv(f)

# %%
menu_df.dtypes
# Out:
# id                       int64
# name                    object
# sponsor                 object
# event                   object
# venue                   object
# place                   object
# physical_description    object
# occasion                object
# notes                   object
# call_number             object
# date                    object
# location                object
# currency                object
# currency_symbol         object
# status                  object
# page_count               int64
# dish_count               int64
# dtype: object

# %%
menu_df.id.astype(int)
menu_df.name.astype(str)
menu_df.sponsor.astype(str)
menu_df.event.astype(str)
menu_df.venue.astype(str)
menu_df.place.astype(str)
menu_df.notes.astype(str)
menu_df.occasion.astype(str)
menu_df.call_number.astype(str)
#menu_df.date.astype(datetime64[D])
menu_df.location.astype(str)
menu_df.currency.astype(str)
menu_df.currency_symbol.astype(str)
menu_df.status.astype(str)
menu_df.page_count.astype(int)
menu_df.dish_count.astype(int)
menu_df.head()
# Out:
#       id name                     sponsor                event       venue  \
# 0  12463  NaN               HOTEL EASTMAN            BREAKFAST  COMMERCIAL
# 1  12464  NaN            REPUBLICAN HOUSE               DINNER  COMMERCIAL
# 2  12465  NaN  NORDDEUTSCHER LLOYD BREMEN  FRUHSTUCK-BREAKFAST  COMMERCIAL
# 3  12466  NaN  NORDDEUTSCHER LLOYD BREMEN                LUNCH  COMMERCIAL
# 4  12467  NaN  NORDDEUTSCHER LLOYD BREMEN               DINNER  COMMERCIAL
#
#                                 place         physical_description occasion  \
# 0                     HOT SPRINGS, AR              CARD; 4.75X7.5;  EASTER;
# 1                       MILWAUKEE, WI   CARD; ILLUS; COL; 7.0X9.0;  EASTER;
# 2  DAMPFER KAISER WILHELM DER GROSSE;    CARD; ILLU; COL; 5.5X8.0;      NaN
# 3  DAMPFER KAISER WILHELM DER GROSSE;    CARD; ILLU; COL; 5.5X8.0;      NaN
# 4  DAMPFER KAISER WILHELM DER GROSSE;  FOLDER; ILLU; COL; 5.5X7.5;      NaN
#
#                                                notes call_number  \
# 0                                                NaN   1900-2822
# 1  WEDGEWOOD BLUE CARD; WHITE EMBOSSED GREEK KEY ...   1900-2825
# 2  MENU IN GERMAN AND ENGLISH; ILLUS, STEAMSHIP A...   1900-2827
# 3  MENU IN GERMAN AND ENGLISH; ILLUS, HARBOR SCEN...   1900-2828
# 4  MENU IN GERMAN AND ENGLISH; ILLUS, HARBOR SCEN...   1900-2829
#
#                    date                     location currency currency_symbol  \
# 0  1900-04-15T00:00:00Z                HOTEL EASTMAN      NaN             NaN
# 1  1900-04-15T00:00:00Z             REPUBLICAN HOUSE      NaN             NaN
# 2  1900-04-16T00:00:00Z  NORDDEUTSCHER LLOYD, BREMEN      NaN             NaN
# 3  1900-04-16T00:00:00Z  NORDDEUTSCHER LLOYD, BREMEN      NaN             NaN
# 4  1900-04-16T00:00:00Z  NORDDEUTSCHER LLOYD, BREMEN      NaN             NaN
#
#      status  page_count  dish_count
# 0  complete           2          67
# 1  complete           2          34
# 2  complete           2          84
# 3  complete           2          63
# 4  complete           4          33

# %%
menu_df['date'] = menu_df.date.str.split('T',expand=True)[0].tolist()

# %%
menu_df.name                 = menu_df.name.str.title().str.replace(' & ',' And ')
menu_df.sponsor              = menu_df.sponsor.str.title().str.replace(' & ',' And ')
menu_df.event                = menu_df.event.str.title().str.replace(' & ',' And ').str.rstrip(';')
menu_df.venue                = menu_df.venue.str.title().str.replace(' & ',' And ').str.rstrip(';')
menu_df.place                = menu_df.place.str.title().str.replace(' & ',' And ').str.rstrip(';')
menu_df.physical_description = menu_df.physical_description.str.title().str.replace(' & ',' And ').str.rstrip(';')
menu_df.occasion             = menu_df.occasion.str.title().str.replace(' & ',' And ').str.rstrip(';')
menu_df.notes                = menu_df.notes.str.title().str.replace(' & ',' And ').str.rstrip(';')
menu_df.location             = menu_df.location.str.title().str.replace(' & ',' And ').str.rstrip(';')
menu_df.status               = menu_df.status.str.title()

# %%
menu_df
# Out:
#           id                                               name  \
# 0      12463                                                NaN
# 1      12464                                                NaN
# 2      12465                                                NaN
# 3      12466                                                NaN
# 4      12467                                                NaN
# ...      ...                                                ...
# 17540  35515                                     Hotel La Salle
# 17541  35516                                          Dennett'S
# 17542  35517                                       The Cortland
# 17543  35518           Hotel Schynige Platte Und Hotel Bellevue
# 17544  35526  Christmas Dinner, Troop F 19: Fort Huachuca, A...
#
#                                                  sponsor                event  \
# 0                                          Hotel Eastman            Breakfast
# 1                                       Republican House               Dinner
# 2                             Norddeutscher Lloyd Bremen  Fruhstuck-Breakfast
# 3                             Norddeutscher Lloyd Bremen                Lunch
# 4                             Norddeutscher Lloyd Bremen               Dinner
# ...                                                  ...                  ...
# 17540                                      Hotel Lasalle                  NaN
# 17541                                          Dennett'S                  NaN
# 17542                                      The Cortlandt                  NaN
# 17543           Hotel Schynige Platte Und Hotel Bellevue                  NaN
# 17544  Christmas Dinner, Troop F 19: Fort Huachuca, A...                  NaN
#
#             venue                              place  \
# 0      Commercial                    Hot Springs, Ar
# 1      Commercial                      Milwaukee, Wi
# 2      Commercial  Dampfer Kaiser Wilhelm Der Grosse
# 3      Commercial  Dampfer Kaiser Wilhelm Der Grosse
# 4      Commercial  Dampfer Kaiser Wilhelm Der Grosse
# ...           ...                                ...
# 17540         NaN                                NaN
# 17541         NaN                                NaN
# 17542         NaN                                NaN
# 17543         NaN                                NaN
# 17544         NaN                                NaN
#
#              physical_description occasion  \
# 0                  Card; 4.75X7.5   Easter
# 1       Card; Illus; Col; 7.0X9.0   Easter
# 2        Card; Illu; Col; 5.5X8.0      NaN
# 3        Card; Illu; Col; 5.5X8.0      NaN
# 4      Folder; Illu; Col; 5.5X7.5      NaN
# ...                           ...      ...
# 17540                         NaN      NaN
# 17541                         NaN      NaN
# 17542                         NaN      NaN
# 17543                         NaN      NaN
# 17544                         NaN      NaN
#
#                                                    notes call_number  \
# 0                                                    NaN   1900-2822
# 1      Wedgewood Blue Card; White Embossed Greek Key ...   1900-2825
# 2      Menu In German And English; Illus, Steamship A...   1900-2827
# 3      Menu In German And English; Illus, Harbor Scen...   1900-2828
# 4      Menu In German And English; Illus, Harbor Scen...   1900-2829
# ...                                                  ...         ...
# 17540                                            1 Image   1913-0746
# 17541                                            1 Image   1913-0747
# 17542                                            1 Image   1913-0748
# 17543                                           4 Images   1913-0749
# 17544                             Fort Huachuca, Arizona         NaN
#
#              date                                           location  \
# 0      1900-04-15                                      Hotel Eastman
# 1      1900-04-15                                   Republican House
# 2      1900-04-16                        Norddeutscher Lloyd, Bremen
# 3      1900-04-16                        Norddeutscher Lloyd, Bremen
# 4      1900-04-16                        Norddeutscher Lloyd, Bremen
# ...           ...                                                ...
# 17540  1913-09-24                                     Hotel La Salle
# 17541  1913-09-24                                          Dennett'S
# 17542  1913-09-24                                       The Cortland
# 17543  1913-09-24           Hotel Schynige Platte Und Hotel Bellevue
# 17544  1920-12-25  Christmas Dinner, Troop F 19: Fort Huachuca, A...
#
#            currency currency_symbol    status  page_count  dish_count
# 0               NaN             NaN  Complete           2          67
# 1               NaN             NaN  Complete           2          34
# 2               NaN             NaN  Complete           2          84
# 3               NaN             NaN  Complete           2          63
# 4               NaN             NaN  Complete           4          33
# ...             ...             ...       ...         ...         ...
# 17540           NaN             NaN  Complete           1          22
# 17541       Dollars               $  Complete           1         125
# 17542       Dollars               $  Complete           1         101
# 17543  Swiss Francs              Fr  Complete           4         161
# 17544           NaN             NaN  Complete          10          32
#
# [17545 rows x 17 columns]

# %%
menu_df.to_csv('..\Data\Menu.csv',encoding='utf-8',float_format='%.2f',index=False)
