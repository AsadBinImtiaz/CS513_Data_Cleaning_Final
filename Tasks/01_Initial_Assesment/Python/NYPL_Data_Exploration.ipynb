# %% [markdown]
# ## Exploration of NYPL Dataset
# ### CS513 - Data Cleansing project
#
# #### First look at data using Jupyter notebook
# Date: 2020-06-29
# Data: Using NYPL Dataset published on 2020-06-16
#
# The dataset contains a mix of simple bibliographic description of the menus (created by The New York Public Library) and the culinary and economic content of the menus themselves.
#
# There are following four files:
# * Dish.csv
# * Menu.csv
# * MenuItem.csv
# * MenuPage.csv

# %% [markdown]
# ## Explore The Data
#
# Import with Pandas
#
# Set pandas default number precision for floats to 2 decimal places

# %%
import pandas as pd
import numpy as np

pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# ### File Names

# %%
DataDir = '../../Data/'
DishFile = 'Dish.csv'
MenuFile = 'Menu.csv'
ItemFile = 'MenuItem.csv'
PageFile = 'MenuPage.csv'

# %% [markdown]
# #### Explore Dishes

# %%
with open (DataDir+DishFile, 'r', encoding='utf-8') as f:
    df_dish = pd.read_csv(f)
df_dish.head(10)
# Out:
#    id                              name  description  menus_appeared  \
# 0   1        Consomme printaniere royal          nan               8
# 1   2                     Chicken gumbo          nan             111
# 2   3               Tomato aux croutons          nan              14
# 3   4                   Onion au gratin          nan              41
# 4   5                       St. Emilion          nan              66
# 5   7                          Radishes          nan            3263
# 6   8            Chicken soup with rice          nan              48
# 7   9                  Clam broth (cup)          nan              14
# 8  10  Cream of new asparagus, croutons          nan               2
# 9  11                Clear green turtle          nan             156
#
#    times_appeared  first_appeared  last_appeared  lowest_price  highest_price
# 0               8            1897           1927          0.20           0.40
# 1             117            1895           1960          0.10           0.80
# 2              14            1893           1917          0.25           0.40
# 3              41            1900           1971          0.25           1.00
# 4              68            1881           1981          0.00          18.00
# 5            3347            1854           2928          0.00          25.00
# 6              49            1897           1961          0.10           0.60
# 7              16            1899           1962          0.15           0.40
# 8               2            1900           1900          0.00           0.00
# 9             156            1893           1937          0.25          60.00

# %% [markdown]
# #### Total Records
#
# 426985 rows, 9 cols

# %%
df_dish.shape
# Out:
# (426985, 9)

# %% [markdown]
# #### Max Length of dish name:
#
# 1387 characters
#
# #### Min Length of dish name:
#
# 1 characters

# %%
max(df_dish.name.apply(len))
# Out:
# 1387

# %%
min(df_dish.name.apply(len))
# Out:
# 1

# %%
df_dish.isnull()
# Out:
#            id   name  description  menus_appeared  times_appeared  \
# 0       False  False         True           False           False
# 1       False  False         True           False           False
# 2       False  False         True           False           False
# 3       False  False         True           False           False
# 4       False  False         True           False           False
# ...       ...    ...          ...             ...             ...
# 426980  False  False         True           False           False
# 426981  False  False         True           False           False
# 426982  False  False         True           False           False
# 426983  False  False         True           False           False
# 426984  False  False         True           False           False
#
#         first_appeared  last_appeared  lowest_price  highest_price
# 0                False          False         False          False
# 1                False          False         False          False
# 2                False          False         False          False
# 3                False          False         False          False
# 4                False          False         False          False
# ...                ...            ...           ...            ...
# 426980           False          False         False          False
# 426981           False          False         False          False
# 426982           False          False         False          False
# 426983           False          False         False          False
# 426984           False          False         False          False
#
# [426985 rows x 9 columns]

# %% [markdown]
# #### Non Null Values in categorical data

# %%
df_dish.description.groupby(df_dish.description.isnull()).count()
# Out:
# description
# True    0
# Name: description, dtype: int64

# %%
df_dish.name.groupby(df_dish.description.isnull()).count()
# Out:
# description
# True    426985
# Name: name, dtype: int64

# %%
len(df_dish.name.str.lower().unique())
# Out:
# 398406

# %% [markdown]
# ####  Summary of categorical data [File Dish.csv]
# **Dish Name**
#
# Null Values: None<br>
# Min Length : 1<br>
# Max Length : 1387<br>
# Unique vals: 398406<br>
#
# *Description*
#
# Null Values: All (426985)<br>
# Min Length : N/A<br>
# Max Length : N/A<br>

# %% [markdown]
# #### Explore numeric data

# %%
df_dish.name.groupby(df_dish.menus_appeared.isnull()).count()
# Out:
# menus_appeared
# False    426985
# Name: name, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
for i, col in enumerate(['times_appeared','first_appeared','last_appeared','lowest_price','highest_price']):
    plt.figure()
    sns.lineplot(y=col, x='menus_appeared', data=df_dish, lw=1)

# %% [markdown]
# - **Name**: (str) 1500 Chars - Name of Dish
# - **Description**  : (str) 1500 Chars - Name of Dish - Always NULL `(Not Usable)`
# - **MenusAppeared**: Integer          - Number of menus the dish appeared
# - **TimesAppeared**: Integer          - Total Unique appearences
# - **FirstAppeared**: Integer (Year)   - Year first appearance
# - **lastAppeared** : Integer (Year)   - Year ID of last appearance
# - **lowestPrice**  : Decimal(2)       - Lowest listed price
# - **highestprice** : Decimal(2)       - highest listed price

# %% [markdown]
# #### Explore Menu file

# %%
with open (DataDir+MenuFile, 'r', encoding='utf-8') as f:
    df_menu = pd.read_csv(f).astype(str)
df_menu.head(5)
# Out:
#       id name                     sponsor                 event       venue  \
# 0  12463  nan               HOTEL EASTMAN             BREAKFAST  COMMERCIAL
# 1  12464  nan            REPUBLICAN HOUSE              [DINNER]  COMMERCIAL
# 2  12465  nan  NORDDEUTSCHER LLOYD BREMEN  FRUHSTUCK/BREAKFAST;  COMMERCIAL
# 3  12466  nan  NORDDEUTSCHER LLOYD BREMEN                LUNCH;  COMMERCIAL
# 4  12467  nan  NORDDEUTSCHER LLOYD BREMEN               DINNER;  COMMERCIAL
#
#                                 place         physical_description occasion  \
# 0                     HOT SPRINGS, AR              CARD; 4.75X7.5;  EASTER;
# 1                    MILWAUKEE, [WI];   CARD; ILLUS; COL; 7.0X9.0;  EASTER;
# 2  DAMPFER KAISER WILHELM DER GROSSE;    CARD; ILLU; COL; 5.5X8.0;      nan
# 3  DAMPFER KAISER WILHELM DER GROSSE;    CARD; ILLU; COL; 5.5X8.0;      nan
# 4  DAMPFER KAISER WILHELM DER GROSSE;  FOLDER; ILLU; COL; 5.5X7.5;      nan
#
#                                                notes call_number keywords  \
# 0                                                nan   1900-2822      nan
# 1  WEDGEWOOD BLUE CARD; WHITE EMBOSSED GREEK KEY ...   1900-2825      nan
# 2  MENU IN GERMAN AND ENGLISH; ILLUS, STEAMSHIP A...   1900-2827      nan
# 3  MENU IN GERMAN AND ENGLISH; ILLUS, HARBOR SCEN...   1900-2828      nan
# 4  MENU IN GERMAN AND ENGLISH; ILLUS, HARBOR SCEN...   1900-2829      nan
#
#   language        date                    location location_type currency  \
# 0      nan  1900-04-15               Hotel Eastman           nan      nan
# 1      nan  1900-04-15            Republican House           nan      nan
# 2      nan  1900-04-16  Norddeutscher Lloyd Bremen           nan      nan
# 3      nan  1900-04-16  Norddeutscher Lloyd Bremen           nan      nan
# 4      nan  1900-04-16  Norddeutscher Lloyd Bremen           nan      nan
#
#   currency_symbol    status page_count dish_count
# 0             nan  complete          2         67
# 1             nan  complete          2         34
# 2             nan  complete          2         84
# 3             nan  complete          2         63
# 4             nan  complete          4         33

# %%
df_menu.isnull()
# Out:
#           id   name  sponsor  event  venue  place  physical_description  \
# 0      False  False    False  False  False  False                 False
# 1      False  False    False  False  False  False                 False
# 2      False  False    False  False  False  False                 False
# 3      False  False    False  False  False  False                 False
# 4      False  False    False  False  False  False                 False
# ...      ...    ...      ...    ...    ...    ...                   ...
# 17540  False  False    False  False  False  False                 False
# 17541  False  False    False  False  False  False                 False
# 17542  False  False    False  False  False  False                 False
# 17543  False  False    False  False  False  False                 False
# 17544  False  False    False  False  False  False                 False
#
#        occasion  notes  call_number  keywords  language   date  location  \
# 0         False  False        False     False     False  False     False
# 1         False  False        False     False     False  False     False
# 2         False  False        False     False     False  False     False
# 3         False  False        False     False     False  False     False
# 4         False  False        False     False     False  False     False
# ...         ...    ...          ...       ...       ...    ...       ...
# 17540     False  False        False     False     False  False     False
# 17541     False  False        False     False     False  False     False
# 17542     False  False        False     False     False  False     False
# 17543     False  False        False     False     False  False     False
# 17544     False  False        False     False     False  False     False
#
#        location_type  currency  currency_symbol  status  page_count  \
# 0              False     False            False   False       False
# 1              False     False            False   False       False
# 2              False     False            False   False       False
# 3              False     False            False   False       False
# 4              False     False            False   False       False
# ...              ...       ...              ...     ...         ...
# 17540          False     False            False   False       False
# 17541          False     False            False   False       False
# 17542          False     False            False   False       False
# 17543          False     False            False   False       False
# 17544          False     False            False   False       False
#
#        dish_count
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 17540       False
# 17541       False
# 17542       False
# 17543       False
# 17544       False
#
# [17545 rows x 20 columns]

# %%
max(df_menu.name.apply(len))
# Out:
# 77

# %%
max(df_menu.sponsor.apply(len))
# Out:
# 127

# %%
max(df_menu.event.apply(len))
# Out:
# 194

# %%
max(df_menu.place.apply(len))
# Out:
# 106

# %%
max(df_menu.physical_description.apply(len))
# Out:
# 118

# %%
max(df_menu.occasion.apply(len))
# Out:
# 97

# %% [markdown]
# - **Id**: (Integer)                   - Identifies a menu
# - **Name**  : (str) 1500 Chars - Name of Dish - Always NULL `(Not Usable)`
# - **Sponsor**: Integer          - Number of menus the dish appeared
# - **Event**: Integer          - Total Unique appearences
# - **Place**: Integer (Year)   - Year first appearance
# - **lastAlastAppearedppeared** : Integer (Year)   - Year ID of last appearance
# - **Occasion**  : Decimal(2)       - Lowest listed price
# - **highestprice** : Decimal(2)       - highest listed price

# %% [markdown]
# #### Explore Menu Item file

# %%
with open (DataDir+ItemFile, 'r', encoding='utf-8') as f:
    df_menu_item = pd.read_csv(f)
df_menu_item.head(5)
# Out:
#    id  menu_page_id  price  high_price  dish_id               created_at  \
# 0   1          1389   0.40         nan     1.00  2011-03-28 15:00:44 UTC
# 1   2          1389   0.60         nan     2.00  2011-03-28 15:01:13 UTC
# 2   3          1389   0.40         nan     3.00  2011-03-28 15:01:40 UTC
# 3   4          1389   0.50         nan     4.00  2011-03-28 15:01:51 UTC
# 4   5          3079   0.50        1.00     5.00  2011-03-28 15:21:26 UTC
#
#                 updated_at  xpos  ypos
# 0  2011-04-19 04:33:15 UTC  0.11  0.25
# 1  2011-04-19 15:00:54 UTC  0.44  0.25
# 2  2011-04-19 19:10:05 UTC  0.14  0.26
# 3  2011-04-19 19:07:01 UTC  0.38  0.26
# 4  2011-04-13 15:25:27 UTC  0.11  0.31

# %% [markdown]
# #### Explore Menu Page file

# %%
with open (DataDir+PageFile, 'r', encoding='utf-8') as f:
    df_menu_page = pd.read_csv(f)
df_menu_page.head(5)
# Out:
#     id  menu_id  page_number image_id  full_height  full_width  \
# 0  119    12460         1.00  1603595      7230.00     5428.00
# 1  120    12460         2.00  1603596      5428.00     7230.00
# 2  121    12460         3.00  1603597      7230.00     5428.00
# 3  122    12460         4.00  1603598      7230.00     5428.00
# 4  123    12461         1.00  1603591      7230.00     5428.00
#
#                                    uuid
# 0  510d47e4-2955-a3d9-e040-e00a18064a99
# 1  510d47e4-2956-a3d9-e040-e00a18064a99
# 2  510d47e4-2957-a3d9-e040-e00a18064a99
# 3  510d47e4-2958-a3d9-e040-e00a18064a99
# 4  510d47e4-2959-a3d9-e040-e00a18064a99

# %%
df_dish.describe()
# Out:
#              id  description  menus_appeared  times_appeared  first_appeared  \
# count 426985.00         0.00       426985.00       426985.00       426985.00
# mean  266583.91          nan            3.04            3.12         1661.43
# std   151626.11          nan           27.71           29.85          666.37
# min        1.00          nan            0.00          -10.00            0.00
# 25%   133484.00          nan            1.00            1.00         1900.00
# 50%   271665.00          nan            1.00            1.00         1914.00
# 75%   400116.00          nan            1.00            1.00         1949.00
# max   519481.00          nan         7748.00         8496.00         2928.00
#
#        last_appeared  lowest_price  highest_price
# count      426985.00     397884.00      397884.00
# mean         1665.19          0.96           1.59
# std           667.04          6.68          12.64
# min             0.00          0.00           0.00
# 25%          1900.00          0.00           0.00
# 50%          1917.00          0.00           0.00
# 75%          1955.00          0.40           0.55
# max          2928.00       1035.00        3050.00

# %%
df_menu.describe()
# Out:
#             id  keywords  language  location_type  page_count  dish_count
# count 17545.00      0.00      0.00           0.00    17545.00    17545.00
# mean  25325.95       nan       nan            nan        3.48       75.71
# std    6431.55       nan       nan            nan        3.30       98.85
# min   12463.00       nan       nan            nan        1.00        0.00
# 25%   20742.00       nan       nan            nan        2.00       20.00
# 50%   26165.00       nan       nan            nan        2.00       35.00
# 75%   30707.00       nan       nan            nan        4.00       93.00
# max   35526.00       nan       nan            nan       74.00     4053.00

# %%
df_menu_item.describe()
# Out:
#               id  menu_page_id     price  high_price    dish_id       xpos  \
# count 1334419.00    1334419.00 888269.00    91990.00 1334178.00 1334419.00
# mean   699048.37      47614.06     12.84        8.09  158823.44       0.39
# std    400644.06      22041.69    499.15       90.05  168475.99       0.22
# min         1.00        130.00      0.00        0.00       1.00       0.00
# 25%    350890.00      32064.00      0.25        0.50    5108.00       0.18
# 50%    703592.00      53386.00      0.40        1.25   81436.50       0.38
# 75%   1047237.50      66828.00      1.00        3.00  334992.75       0.57
# max   1388524.00      77425.00 180000.00     7800.00  519481.00       0.99
#
#             ypos
# count 1334419.00
# mean        0.55
# std         0.22
# min         0.00
# 25%         0.37
# 50%         0.57
# 75%         0.74
# max         1.00

# %%
df_menu_page.describe()
# Out:
#             id  menu_id  page_number  full_height  full_width
# count 66937.00 66937.00     65735.00     66608.00    66608.00
# mean  42719.76 25653.58         3.76      3859.10     2778.59
# std   21274.00  6158.83         4.91      1156.01      970.29
# min     119.00 12460.00         1.00       616.00      558.00
# 25%   27108.00 21743.00         1.00      2988.00     2120.00
# 50%   43894.00 26202.00         2.00      3630.00     2527.00
# 75%   60696.00 30531.00         4.00      4617.25     3295.25
# max   77431.00 35526.00        74.00     12044.00     9175.00

# %%
#END
